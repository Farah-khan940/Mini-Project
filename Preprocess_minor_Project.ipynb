# %% [markdown]
# <a href="https://colab.research.google.com/github/Farah-khan940/Mini-Project/blob/main/Preprocess_minor_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/2022-chevrolet-corvette-z06-1607016574.jpg?crop=0.737xw:0.738xh;0.181xw,0.218xh&resize=640:*-O pic.jpg
# Out:
# --2021-06-27 04:55:28--  https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/2022-chevrolet-corvette-z06-1607016574.jpg?crop=0.737xw:0.738xh
# Resolving hips.hearstapps.com (hips.hearstapps.com)... 151.101.0.155, 151.101.64.155, 151.101.128.155, ...
# Connecting to hips.hearstapps.com (hips.hearstapps.com)|151.101.0.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223810 (219K) [image/jpeg]
# Saving to: ‘2022-chevrolet-corvette-z06-1607016574.jpg?crop=0.737xw:0.738xh’
#
# 2022-chevrolet-corv 100%[===================>] 218.56K  --.-KB/s    in 0.03s
#
# 2021-06-27 04:55:29 (7.97 MB/s) - ‘2022-chevrolet-corvette-z06-1607016574.jpg?crop=0.737xw:0.738xh’ saved [223810/223810]
#
# /bin/bash: 0.181xw,0.218xh: command not found
# /bin/bash: pic.jpg: command not found

# %%
import matplotlib.pyplot as plt
img=plt.imread('/content/drive/MyDrive/bike.jpg')
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (800, 1200, 3)

# %%
img
#img
#unint8
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
import cv2
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
gray.shape
# Out:
# (800, 1200)

# %%
import numpy as np
a=np.array([[1,2,3],
            [4,5,6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#Flatten
a.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread  # This normalizes the pixel values
from skimage.transform  import resize

# %%
#Opencv - BGR2GRAY
#Skimage =rgb2gray

# %%
#Curse of Dimensionality-If number of features are more ,then accuracy reduces

# %%
# Displaying the image
path='/content/drive/MyDrive/bike.jpg'
img=plt.imread(path)
plt.imshow(img)
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt
from skimage.io import imread  # This normalizes the pixel values
from skimage.transform  import resize 
datadir='/content/drive/MyDrive/Images'
categories=['Bikes','Cars'] #Name the folder with these categories
target=[]
flat_data=[]

for i in categories:
  path=os.path.join(datadir,i)
  # print(path)
  for img in os.listdir(path):
    print(img)
    img_array=imread(os.path.join(path,img))
    img_resize=resize( img_array,(150,150,3))
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)
    plt.imshow(img_resize)
    plt.show()
    flat_data=np.array(flat_data)
    target=np.array(target)
# Out:
# bike.jpg
# bike1.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-c16bed8b9de2> in <module>()
#      17     img_array=imread(os.path.join(path,img))
#      18     img_resize=resize( img_array,(150,150,3))
# ---> 19     flat_data.append(np.ndarray.flatten(img_resize))
#      20     target.append(i)
#      21     plt.imshow(img_resize)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
from skimage.color import rgb2gray

img_resize=resize(img_array,(50,50))
img_gray=rgb2gray(img_resize)
plt.imshow(img_gray,cmap='gray')
img_gray.size
# Out:
# 2500
